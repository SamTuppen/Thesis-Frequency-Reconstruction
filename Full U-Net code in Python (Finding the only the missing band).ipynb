# %% [markdown]
# # U-Net Full implementation

# %% [markdown]
# ## Load necessary packages

# %%
import random
import os
import sys
import warnings

from tqdm import tqdm

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
from numpy.fft import fft, ifft
import matplotlib.pyplot as plt
import scipy.io
import scipy
from scipy.signal import butter, filtfilt
import segyio


from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dropout, Lambda, Layer, ReLU, Add
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, BatchNormalization
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import concatenate, Concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import backend as K

# %% [markdown]
# ## Define parameters

# %%
## Parameters used in gathers
Ntrainingsamples = 300     # Number of gathers windowed to generate training examples[-]
Ntestsamples = 10          #Number of test examples for the network to interpolate
dt = 0.008                 # Sampling rate [s]
Fs = 1/dt                  # Sampling frequency (500 Hz)
noiselevel = 0.0           # Percent noise
RandomFilts = 1            # Turn on for using 2 random 10 Hz frequency ranges

TracesPerGather = 126


#Windowing Parameters: (Could merge with the parameters below)
input_width = 64          #Columns in window (space)
input_height = 512         #Rows in window (time)
overlap = 0.5              #Ratio of overlap

start_time = 0           #Where to start reading each gather incase you wish to cut off some samples
end_time = 1115            #Where to stop reading each gather -1 to select the last sample

#Parameters used in U-net:
IMG_WIDTH = input_width
IMG_HEIGHT = input_height
IMG_CHANNELS = 1

dir_path = ''

dropout = 0.0


## File location:
TRAINX_PATH = '/Users/samtu/Documents/'
# filename = 'NorthSeaLine.sgy'
# filename = 'NoSI_short.segy'
filename = 'PlutoOrig.sgy'

# %% [markdown]
# ### Test for GPU

# %%
print(f'TensorFlow Version:',tf.__version__)
print(tf.config.list_physical_devices())
# Out:
# TensorFlow Version: 2.7.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Define functions

# %%
def myFilterStop(data,flp,fhi,delt):
    #c - input time series
    #flp - lowpass corner freq of filter
    #fhi - highpass corner freq
    #delt - sampeling interval of the data
    #to avoid edge effects
    
    y = data.shape[0]
    data2 = np.vstack((np.flipud(data),data,np.flipud(data)))
    slope = np.hanning(2*y).reshape((2*y,1))
    slope1 = slope[0:y]
    slope2 = np.ones((y,1))
    slope3 = slope[y:2*y]
    slope = np.vstack((slope1, slope2, slope3))

    #multiply with a nice window function
    for i in range(3*y):
        data2[i] = data2[i] * slope[i]

    n = 5 #order Butterworth filter
    fnq = 1.0 / (2*delt) #Nyquist
    Wn = [flp/fnq, fhi/fnq] #Butterworth non-dim freq
    b,a = butter(n,Wn,'bandstop',output='ba') #construct the filter
    d = filtfilt(b,a,data2,axis=0) #zero phase filter

    #pick out the part that I actually want
    d = d[1*y + 0:2*y , :]
    return d

def myFilterPass(data,flp,fhi,delt):
    #c - input time series
    #flp - lowpass corner freq of filter
    #fhi - highpass corner freq
    #delt - sampeling interval of the data
    #to avoid edge effects
    
    y = data.shape[0]
    data2 = np.vstack((np.flipud(data),data,np.flipud(data)))
    slope = np.hanning(2*y).reshape((2*y,1))
    slope1 = slope[0:y]
    slope2 = np.ones((y,1))
    slope3 = slope[y:2*y]
    slope = np.vstack((slope1, slope2, slope3))

    #multiply with a nice window function
    for i in range(3*y):
        data2[i] = data2[i] * slope[i]

    n = 5 #order Butterworth filter
    fnq = 1.0 / (2*delt) #Nyquist
    Wn = [flp/fnq, fhi/fnq] #Butterworth non-dim freq
    b,a = butter(n,Wn,'bandpass',output='ba') #construct the filter
    d = filtfilt(b,a,data2,axis=0) #zero phase filter

    #pick out the part that I actually want
    d = d[1*y + 0:2*y , :]
    return d

def MyLoss(y_true, y_pred):
    
    y_true_t = tf.transpose(y_true, [0, 3, 2, 1])
    y_pred_t = tf.transpose(y_pred, [0, 3, 2, 1])
    
    h = tf.keras.losses.Huber()
    L1 = h(y_true, y_pred)
    
    #Doesn't work
    p1 = tf.math.angle(tf.signal.rfft(y_true_t))
    p2 = tf.math.angle(tf.signal.rfft(y_pred_t))
    
    out = tf.reduce_mean(tf.abs(p1-p2))/(2*np.pi)
    
#     print(y_true)
#     print(tf.signal.rfft(y_true))
#     K.print_tensor(y_true, message='y_true = ')
#     K.print_tensor(p2, message='p2 = ')
    
    return   1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0)) + L1 #+ out


# def MyLoss(y_true, y_pred):
#     h = tf.keras.losses.Huber()
#     L1 = h(y_true, y_pred)
    
#     p1 = tf.math.angle(tf.signal.rfft(y_true))
#     p2 = tf.math.angle(tf.signal.rfft(y_pred))
    
#     out = tf.reduce_mean(tf.abs(p1-p2))/np.pi*2000
    
#     return L1 + out

#Defining necessary layers

def CoordAtt(x, reduction=32, bn_trainable=False):
    def coord_act(x):
        tmpx = (ReLU(max_value=6)(x + 3)) / 6
        x = x * tmpx
        return x

    x_shape = x.shape.as_list()
    [b, h, w, c] = x_shape
    
    x_h = AveragePooling2D(pool_size=(1, w), strides=(1, 1), data_format='channels_last')(x)
    x_w = AveragePooling2D(pool_size=(h, 1), strides=(1, 1), data_format='channels_last')(x)
    x_w = K.permute_dimensions(x_w, [0, 2, 1, 3])
    
    y = concatenate(inputs=[x_h, x_w], axis=1)
    
    mip = max(8, c // reduction)
    
    y = Conv2D(filters=mip, kernel_size=(1, 1), strides=(1, 1), padding='valid')(y)
    y = BatchNormalization(trainable=bn_trainable)(y)
    y = coord_act(y)
    
    x_h, x_w = Lambda(tf.split, arguments={'axis': 1, 'num_or_size_splits': [h, w]})(y)
    
    x_w = K.permute_dimensions(x_w, [0, 2, 1, 3])
    
    a_h = Conv2D(filters=c, kernel_size=(1, 1), strides=(1, 1), padding='valid', activation="sigmoid")(x_h)
    a_w = Conv2D(filters=c, kernel_size=(1, 1), strides=(1, 1), padding='valid', activation="sigmoid")(x_w)
    
    out = x * a_h * a_w
    
    return out


def conv_block(inp, num_filters):
    x = Conv2D(num_filters, (3,3), padding="same", activation="relu")(inp)
    x = Conv2D(num_filters, (3,3), padding="same", activation="relu")(x)
#     coordinate_attention = CoordAtt(x)
#     x = Add()([coordinate_attention, x])
    return x

def encoder_block(inp, num_filters):
    x = conv_block(inp, num_filters) #also the skip feature
    p = MaxPooling2D((2, 2))(x) #output to the next block
    return x, p

def decoder_block(inp, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (3, 3), strides=(2,2), padding="same")(inp)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

# %% [markdown]
# ## Generate Training data (by windowing)

# %%
shifting = 0*80
# Get and resize train images and masks
# Number of layers is num. gather * num. windows per gather

print('Getting training images ... ')


#Read the SEGY with segyio and split into gathers
counter = 0

#Define ouput windows
output_width = np.round(overlap*input_width) 
output_height = np.round(overlap*input_height)
        

with segyio.open(TRAINX_PATH + filename, ignore_geometry=True) as f:
    
    NumWindows = int(np.floor(TracesPerGather/output_width)*np.floor(len(f.samples)/output_height))
    
    #Define matrices to be filledin
    X_train = np.zeros((Ntrainingsamples * NumWindows*4, input_height, input_width, 1))
    Y_train = np.zeros((Ntrainingsamples * NumWindows*4, input_height, input_width, 1))
    
    X_test = np.zeros((Ntestsamples * NumWindows*4, input_height, input_width, 1))
    Y_test = np.zeros((Ntestsamples * NumWindows*4, input_height, input_width, 1))
    
    #Frequencies to be removed, note that this number should be changed in case the number/type of filters change
    freqRemoveTrain = np.zeros((Ntrainingsamples * NumWindows*4,4))
    freqRemoveTest = np.zeros((Ntestsamples * NumWindows*4,4))
    
    for k in tqdm(np.arange(Ntrainingsamples)+shifting):
        
        #Select the traces of each gather
        gather = f.trace.raw[:].T.reshape((len(f.samples),f.tracecount))[start_time:end_time,k+k*(TracesPerGather-1) : k+(k+1)*(TracesPerGather-1)]
        
        #Filter out frequencies
        freqRemoveTrain[k,0] = 30;
        freqRemoveTrain[k,1] = freqRemoveTrain[k,0] + 5;

        gatherfilt = myFilterStop(gather,freqRemoveTrain[k,0],freqRemoveTrain[k,1],dt);
        gather = myFilterPass(gather,freqRemoveTrain[k,0],freqRemoveTrain[k,1],dt);
        
        #Apply windowing to gather
        for j in np.arange(0, gather.shape[0], output_height):
            for i in np.arange(0, gather.shape[1], output_width):

                input_window = gather[int(np.min([np.max([0,j-output_height/2]) , gather.shape[0]-input_height])):
                                      int(np.min([np.max([0,j-output_height/2]) + input_height , gather.shape[0]])),
                                      int(np.min([np.max([0,i-output_width/2]) , gather.shape[1]-input_width])):
                                      int(np.min([np.max([0,i-output_width/2]) + input_width , gather.shape[1]]))]
                
                input_windowfilt = gatherfilt[int(np.min([np.max([0,j-output_height/2]) , gatherfilt.shape[0]-input_height])):
                                              int(np.min([np.max([0,j-output_height/2]) + input_height , gatherfilt.shape[0]])),
                                              int(np.min([np.max([0,i-output_width/2]) , gatherfilt.shape[1]-input_width])):
                                              int(np.min([np.max([0,i-output_width/2]) + input_width , gatherfilt.shape[1]]))]

                #Add noise
                input_windowfilt = input_windowfilt + noiselevel * np.random.rand(input_height,input_width)
                
                #Fill window into training matrix
                X_train[counter] = input_windowfilt.reshape(input_height,input_width,1)
                Y_train[counter] = input_window.reshape(input_height,input_width,1)
    
    
                #Add to counter
                counter += 1
            
    print('Getting test images ... ')
    counter = 0
    
    gathernormfactor = np.zeros((Ntestsamples * NumWindows*4,1))
    gatherfiltnormfactor = np.zeros((Ntestsamples * NumWindows*4,1))
    
    for k in tqdm(np.arange(Ntrainingsamples, Ntrainingsamples + Ntestsamples)+shifting):
        
        #Select the traces of each gather
        gather = f.trace.raw[:].T.reshape((len(f.samples),f.tracecount))[start_time:end_time,k+k*(TracesPerGather-1) : k+(k+1)*(TracesPerGather-1)]
        
        #Filter out frequencies
        freqRemoveTest[k,0] = 30;
        freqRemoveTest[k,1] = freqRemoveTest[k,0] + 5;

        gatherfilt = myFilterStop(gather,freqRemoveTest[k,0],freqRemoveTest[k,1],dt);
        gather = myFilterPass(gather,freqRemoveTest[k,0],freqRemoveTest[k,1],dt);
        
        #Apply windowing to gather
        for j in np.arange(0, gather.shape[0], output_height):
            for i in np.arange(0, gather.shape[1], output_width):

                input_window = gather[int(np.min([np.max([0,j-output_height/2]) , gather.shape[0]-input_height])):
                                      int(np.min([np.max([0,j-output_height/2]) + input_height , gather.shape[0]])),
                                      int(np.min([np.max([0,i-output_width/2]) , gather.shape[1]-input_width])):
                                      int(np.min([np.max([0,i-output_width/2]) + input_width , gather.shape[1]]))]
                
                input_windowfilt = gatherfilt[int(np.min([np.max([0,j-output_height/2]) , gather.shape[0]-input_height])):
                                              int(np.min([np.max([0,j-output_height/2]) + input_height , gather.shape[0]])),
                                              int(np.min([np.max([0,i-output_width/2]) , gather.shape[1]-input_width])):
                                              int(np.min([np.max([0,i-output_width/2]) + input_width , gather.shape[1]]))]
                
                #Add noise
                input_windowfilt = input_windowfilt + noiselevel * np.random.rand(input_height,input_width)
                
                
                #Fill window into training matrix
                X_test[counter] = input_windowfilt.reshape(input_height,input_width,1)
                Y_test[counter] = input_window.reshape(input_height,input_width,1)
    
    
                #Add to counter
                counter += 1    
    f.close()

print('Deleting empty arrays...')
freqRemoveTrain = freqRemoveTrain[~np.all(X_train == 0, axis=(1,2,3))]
freqRemoveTest = freqRemoveTest[~np.all(X_test == 0, axis=(1,2,3))]
# gathernormfactor = gathernormfactor[[~np.all(X_test == 0, axis=(1,2,3))]]
# gatherfiltnormfactor = gatherfiltnormfactor[~np.all(X_test == 0, axis=(1,2,3))]
X_train = X_train[~np.all(X_train == 0, axis=(1,2,3))]
X_test = X_test[~np.all(Y_test == 0, axis=(1,2,3))]
Y_train = Y_train[~np.all(Y_train == 0, axis=(1,2,3))]
Y_test = Y_test[~np.all(Y_test == 0, axis=(1,2,3))]

print('Normalizing...')
#Normalization:
normfac = np.max(np.array([
                              np.max(np.abs(X_train)), 
                              np.max(np.abs(Y_train)),
                              np.max(np.abs(X_test)), 
                              np.max(np.abs(Y_test))]))
X_train = ((X_train / normfac) + 1) / 2;
Y_train = ((Y_train / normfac) + 1) / 2;
X_test = ((X_test / normfac) + 1) / 2;
Y_test = ((Y_test / normfac) + 1) / 2;

print('Deleting duplicate arrays from training data...')
#REMOVE DUPLICATES
_, b = np.unique(Y_train, return_index = 1 ,axis=0)
X_train = X_train[b] 
Y_train = Y_train[b]

del gather
del _
del b

print('Done!')
# Out:
# Getting training images ...
# 100%|██████████| 300/300 [06:43<00:00,  1.34s/it]
# Getting test images ...
# 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Deleting empty arrays...
# Normalizing...
# Deleting duplicate arrays from training data...
# Done!

# %% [markdown]
# ## Build Neural Net

# %%
def build_unet(input_shape, start_neurons):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, start_neurons * 1) 
    s2, p2 = encoder_block(p1, start_neurons * 2)
    s3, p3 = encoder_block(p2, start_neurons * 4)
    
    b1 = conv_block(p3, start_neurons * 16)
    
    d3 = decoder_block(b1, s3, start_neurons * 4)
    d2 = decoder_block(d3, s2, start_neurons * 2)
    d1 = decoder_block(d2, s1, start_neurons * 1)

    outputs = Conv2D(1, (1,1), padding="same")(d1)

    model = Model(inputs, outputs, name="U-Net")
    return model

input_shape = (input_height, input_width, 1)
model = build_unet(input_shape, 32)
model.compile(loss= "mean_squared_error" , optimizer="adam", metrics=["mean_squared_error"])
K.set_value(model.optimizer.learning_rate, 0.001)
model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 64, 1)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 512, 64, 32)  320         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 512, 64, 32)  9248        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 32, 32)  0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 256, 32, 64)  18496       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 256, 32, 64)  36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 16, 64)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 16, 128  73856       ['max_pooling2d_1[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 128, 16, 128  147584      ['conv2d_4[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 8, 128)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 8, 512)   590336      ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 8, 512)   2359808     ['conv2d_6[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 128, 16, 128  589952     ['conv2d_7[0][0]']
#  ose)                           )
#
#  concatenate (Concatenate)      (None, 128, 16, 256  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_5[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 16, 128  295040      ['concatenate[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 16, 128  147584      ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 32, 64)  73792      ['conv2d_9[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 256, 32, 128  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 256, 32, 64)  73792       ['concatenate_1[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 256, 32, 64)  36928       ['conv2d_10[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 512, 64, 32)  18464      ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 512, 64, 64)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 64, 32)  18464       ['concatenate_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 512, 64, 32)  9248        ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 512, 64, 1)   33          ['conv2d_13[0][0]']
#
# ==================================================================================================
# Total params: 4,499,873
# Trainable params: 4,499,873
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Fitting the Model

# %%
earlystopper = EarlyStopping(patience=15, 
                             verbose=1)
checkpointer = ModelCheckpoint('model_unet_checkpoint.h5', 
                               verbose=1, 
                               save_best_only=True)

history = model.fit(X_train, 
                    Y_train, 
                    validation_split=0.2, 
                    batch_size=4, 
                    epochs=20, 
                    shuffle=1,
                    callbacks=[earlystopper, checkpointer]
                   )
# Out:
# Epoch 1/20
# 960/960 [==============================] - ETA: 0s - loss: 9.7416e-04 - mean_squared_error: 9.7416e-04
# Epoch 00001: val_loss improved from inf to 0.00004, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 55s 53ms/step - loss: 9.7416e-04 - mean_squared_error: 9.7416e-04 - val_loss: 3.9372e-05 - val_mean_squared_error: 3.9372e-05
# Epoch 2/20
# 959/960 [============================>.] - ETA: 0s - loss: 3.4249e-05 - mean_squared_error: 3.4249e-05 ETA: 1s - loss: 3.4167e
# Epoch 00002: val_loss improved from 0.00004 to 0.00004, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 3.4254e-05 - mean_squared_error: 3.4254e-05 - val_loss: 3.7737e-05 - val_mean_squared_error: 3.7737e-05
# Epoch 3/20
# 960/960 [==============================] - ETA: 0s - loss: 3.4163e-05 - mean_squared_error: 3.4163e-05
# Epoch 00003: val_loss improved from 0.00004 to 0.00003, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 3.4163e-05 - mean_squared_error: 3.4163e-05 - val_loss: 3.0458e-05 - val_mean_squared_error: 3.0458e-05
# Epoch 4/20
# 959/960 [============================>.] - ETA: 0s - loss: 3.3701e-05 - mean_squared_error: 3.3701e-05
# Epoch 00004: val_loss improved from 0.00003 to 0.00003, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 3.3692e-05 - mean_squared_error: 3.3692e-05 - val_loss: 2.9971e-05 - val_mean_squared_error: 2.9971e-05
# Epoch 5/20
# 959/960 [============================>.] - ETA: 0s - loss: 3.0015e-05 - mean_squared_error: 3.0015e-05
# Epoch 00005: val_loss did not improve from 0.00003
# 960/960 [==============================] - 51s 53ms/step - loss: 3.0005e-05 - mean_squared_error: 3.0005e-05 - val_loss: 3.0137e-05 - val_mean_squared_error: 3.0137e-05
# Epoch 6/20
# 960/960 [==============================] - ETA: 0s - loss: 2.7215e-05 - mean_squared_error: 2.7215e-05
# Epoch 00006: val_loss did not improve from 0.00003
# 960/960 [==============================] - 51s 53ms/step - loss: 2.7215e-05 - mean_squared_error: 2.7215e-05 - val_loss: 4.4428e-05 - val_mean_squared_error: 4.4428e-05
# Epoch 7/20
# 960/960 [==============================] - ETA: 0s - loss: 2.4912e-05 - mean_squared_error: 2.4912e-05
# Epoch 00007: val_loss improved from 0.00003 to 0.00003, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 2.4912e-05 - mean_squared_error: 2.4912e-05 - val_loss: 2.5132e-05 - val_mean_squared_error: 2.5132e-05
# Epoch 8/20
# 959/960 [============================>.] - ETA: 0s - loss: 2.3779e-05 - mean_squared_error: 2.3779e-05
# Epoch 00008: val_loss did not improve from 0.00003
# 960/960 [==============================] - 51s 53ms/step - loss: 2.3770e-05 - mean_squared_error: 2.3770e-05 - val_loss: 2.7266e-05 - val_mean_squared_error: 2.7266e-05
# Epoch 9/20
# 960/960 [==============================] - ETA: 0s - loss: 2.2370e-05 - mean_squared_error: 2.2370e-05
# Epoch 00009: val_loss improved from 0.00003 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 2.2370e-05 - mean_squared_error: 2.2370e-05 - val_loss: 2.4503e-05 - val_mean_squared_error: 2.4503e-05
# Epoch 10/20
# 960/960 [==============================] - ETA: 0s - loss: 2.1264e-05 - mean_squared_error: 2.1264e-05
# Epoch 00010: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 2.1264e-05 - mean_squared_error: 2.1264e-05 - val_loss: 2.3987e-05 - val_mean_squared_error: 2.3987e-05
# Epoch 11/20
# 959/960 [============================>.] - ETA: 0s - loss: 1.9876e-05 - mean_squared_error: 1.9876e-05
# Epoch 00011: val_loss did not improve from 0.00002
# 960/960 [==============================] - 51s 53ms/step - loss: 1.9876e-05 - mean_squared_error: 1.9876e-05 - val_loss: 2.6791e-05 - val_mean_squared_error: 2.6791e-05
# Epoch 12/20
# 959/960 [============================>.] - ETA: 0s - loss: 1.8990e-05 - mean_squared_error: 1.8990e-05
# Epoch 00012: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 1.8999e-05 - mean_squared_error: 1.8999e-05 - val_loss: 2.3117e-05 - val_mean_squared_error: 2.3117e-05
# Epoch 13/20
# 960/960 [==============================] - ETA: 0s - loss: 1.8082e-05 - mean_squared_error: 1.8082e-05
# Epoch 00013: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 1.8082e-05 - mean_squared_error: 1.8082e-05 - val_loss: 2.0814e-05 - val_mean_squared_error: 2.0814e-05
# Epoch 14/20
# 960/960 [==============================] - ETA: 0s - loss: 1.7287e-05 - mean_squared_error: 1.7287e-05
# Epoch 00014: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 1.7287e-05 - mean_squared_error: 1.7287e-05 - val_loss: 2.0464e-05 - val_mean_squared_error: 2.0464e-05
# Epoch 15/20
# 960/960 [==============================] - ETA: 0s - loss: 1.6234e-05 - mean_squared_error: 1.6234e-05
# Epoch 00015: val_loss did not improve from 0.00002
# 960/960 [==============================] - 60s 62ms/step - loss: 1.6234e-05 - mean_squared_error: 1.6234e-05 - val_loss: 2.6195e-05 - val_mean_squared_error: 2.6195e-05
# Epoch 16/20
# 960/960 [==============================] - ETA: 0s - loss: 1.5620e-05 - mean_squared_error: 1.5620e-05
# Epoch 00016: val_loss did not improve from 0.00002
# 960/960 [==============================] - 55s 57ms/step - loss: 1.5620e-05 - mean_squared_error: 1.5620e-05 - val_loss: 2.0678e-05 - val_mean_squared_error: 2.0678e-05
# Epoch 17/20
# 960/960 [==============================] - ETA: 0s - loss: 1.4859e-05 - mean_squared_error: 1.4859e-05
# Epoch 00017: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 52s 54ms/step - loss: 1.4859e-05 - mean_squared_error: 1.4859e-05 - val_loss: 1.9071e-05 - val_mean_squared_error: 1.9071e-05
# Epoch 18/20
# 960/960 [==============================] - ETA: 0s - loss: 1.4283e-05 - mean_squared_error: 1.4283e-05
# Epoch 00018: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 53s 55ms/step - loss: 1.4283e-05 - mean_squared_error: 1.4283e-05 - val_loss: 1.8343e-05 - val_mean_squared_error: 1.8343e-05
# Epoch 19/20
# 960/960 [==============================] - ETA: 0s - loss: 1.3581e-05 - mean_squared_error: 1.3581e-05
# Epoch 00019: val_loss did not improve from 0.00002
# 960/960 [==============================] - 52s 54ms/step - loss: 1.3581e-05 - mean_squared_error: 1.3581e-05 - val_loss: 2.1183e-05 - val_mean_squared_error: 2.1183e-05
# Epoch 20/20
# 959/960 [============================>.] - ETA: 0s - loss: 1.3088e-05 - mean_squared_error: 1.3088e-05
# Epoch 00020: val_loss improved from 0.00002 to 0.00002, saving model to model_unet_checkpoint.h5
# 960/960 [==============================] - 51s 53ms/step - loss: 1.3090e-05 - mean_squared_error: 1.3090e-05 - val_loss: 1.7901e-05 - val_mean_squared_error: 1.7901e-05

# %% [markdown]
# ## Plotting the progression

# %%
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']
acc = history.history['mean_squared_error']
val_acc = history.history['val_mean_squared_error']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '--b', label='Training error')
plt.plot(epochs, val_acc, 'r', label='Validation error')
plt.title('Training and validation error')
plt.legend()

plt.figure()

plt.plot(epochs, loss, '--b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Make Predictions

# %%
# model = load_model('model_unet_checkpoint.h5', compile=False)
# model.compile(loss=MyLoss, optimizer='adam', metrics=["mean_squared_error"])

preds_test = model.predict(X_test, verbose=1)
# Out:
# 7/7 [==============================] - 5s 293ms/step

# %% [markdown]
# ### Prediction test data (unseen)

# %%
# Perform a sanity check on some random validation samples

ix = random.randint(0, len(preds_test)-1)
print(ix)
# for ix in range(len(preds_test)):
#     print(ix)
#     print(abs(np.array([Y_test[ix,:,:] - preds_test[ix,:,:]])).max())

f = plt.figure(figsize=(10,15))
ax = f.add_subplot(221)
plt.imshow(X_test[ix,:,:], cmap='gray')
plt.colorbar()
plt.title('Filtered + Noise')
plt.clim(0,1)

ax2 = f.add_subplot(222)
plt.imshow(Y_test[ix,:,:], cmap='gray')
plt.title('True data (Objective)')
plt.colorbar()
plt.clim(0,1)

ax3 = f.add_subplot(224)
plt.imshow(preds_test[ix,:,:], cmap='gray')
plt.title('Fitted data from Neural Network')
plt.colorbar()
plt.clim(0,1)

ax4 = f.add_subplot(223)
plt.imshow(abs(Y_test[ix,:,:] - preds_test[ix,:,:]),cmap = 'Reds')
plt.title('Absolute error')
plt.colorbar()
# plt.clim(0,0.05)
plt.show()

f = plt.figure(figsize=(10,15))
ax = f.add_subplot(131)
plt.imshow(abs(Y_test[ix,:,:] - preds_test[ix,:,:]),cmap = 'Reds')
plt.clim(0, 0.05)
plt.title('Absolute error of approximation')

ax = f.add_subplot(132)
plt.imshow(abs(Y_test[ix,:,:] - X_test[ix,:,:]),cmap = 'Reds')
plt.clim(0, 0.05)
plt.title('Error Objective and Test Data')


ax = f.add_subplot(133)
plt.imshow(abs(abs(Y_test[ix,:,:] - X_test[ix,:,:])-abs(Y_test[ix,:,:] - preds_test[ix,:,:])),cmap = 'Reds')
plt.title('Difference of both error plots')
plt.clim(0, 0.05)
plt.show()
# Out:
# 188

# %% [markdown]
# # Plotting the frequency and phase

# %%
##Frequency Plotting
trace = 30
windownumber = random.randint(0, len(preds_test)-1)

print(Y_test.shape)
print(preds_test.shape)
print(freqRemoveTest[windownumber,:])

input_gather = Y_test[windownumber,:,trace,:]
filtered = X_test[windownumber,:,trace,:]
out = preds_test[windownumber,:,trace,:]

f1=np.abs(fft(input_gather,axis=0))
f2=np.abs(fft(out,axis=0))
f3=np.abs(fft(filtered,axis=0))

x=np.linspace(0,1/dt,len(out)).reshape(len(out),1);

p1 = np.angle(fft(input_gather,axis=0))*180/np.pi
p2 = np.angle(fft(out,axis=0))*180/np.pi
p3 = np.angle(fft(filtered,axis=0))*180/np.pi

idx = (30<=x) * (x<=35)
RMS = np.mean(abs(p1[idx]-p2[idx]))
print(RMS)

#Load Filter boundaries
fig = plt.figure(figsize=(10,15))
fig.add_subplot(2,1,1)

# plt.axvspan(freqRemoveTest[windownumber,0], freqRemoveTest[windownumber,1], color='green', alpha=0.2)
# plt.axvspan(freqRemoveTest[windownumber,2], freqRemoveTest[windownumber,3], color='red', alpha=0.2)
plt.axvspan(30, 35, color='green', alpha=0.1)

plt.plot(x,20*np.log10(f1),'-or',label='Ground Truth', markerfacecolor='None')
plt.plot(x,20*np.log10(f2),'--.b',label='Output')
plt.plot(x,20*np.log10(f3),'--g',color='#00841a',label='Filtered + Noise')
plt.xlim(29,36)
# plt.ylim(-40,30)
plt.title('Frequency response');
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude [dB]')
plt.grid()
plt.legend()

fig.add_subplot(2,1,2)
plt.plot(x,p1,'-or',label='Ground Truth', markerfacecolor='None')
plt.plot(x,p2,'--.b',label='Output')
plt.plot(x,p3,'--g',label='missing')
plt.axvspan(30, 35, color='green', alpha=0.1)
# plt.axvspan(freqRemoveTest[windownumber,0], freqRemoveTest[windownumber,1], color='green', alpha=0.2)
# plt.axvspan(freqRemoveTest[windownumber,2], freqRemoveTest[windownumber,3], color='red', alpha=0.2)
# plt.xlim(29,36)
# plt.ylim(-np.pi,np.pi)
plt.xlabel('Frequency [Hz]')
plt.ylabel('Phase [degrees]')
plt.legend()
plt.grid()
plt.show()

f = plt.figure(figsize=(10,15))
ax = f.add_subplot(121)
plt.imshow(Y_test[windownumber,:,:,:], cmap='gray')
plt.title('Objective')
plt.clim(0,1)

ax = f.add_subplot(122)
plt.imshow(preds_test[windownumber,:,:,:], cmap='gray')
plt.title('Prediction')
plt.clim(0,1)
plt.show()
# Out:
# (200, 512, 64, 1)
# (200, 512, 64, 1)
# [0. 0. 0. 0.]
# 60.91101947059843
# C:\Users\samtu\AppData\Local\Temp/ipykernel_9244/2943115192.py:37: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "--g" (-> color='g'). The keyword argument will take precedence.
#   plt.plot(x,20*np.log10(f3),'--g',color='#00841a',label='Filtered + Noise')

# %% [markdown]
# ## RMS Calculation

# %%
# abs(np.angle(fft(preds_test, axis=0)) - Y_test)
idx = (30<=x) * (x<=35)

count = 0
RMS = np.zeros((100*256,1))
for k in range(len(Y_test)):
    for i in range(Y_test.shape[2]):
        ft1 = np.angle(fft(Y_test[k,:,i,:], axis = 0))
        ft2 = np.angle(fft(preds_test[k,:,i,:], axis = 0))
        RMS[count] = np.mean(abs(ft1[idx]-ft2[idx]))
        count += 1
        
RMS = RMS[RMS != 0]
RMS = np.mean(RMS)*180/np.pi
print(RMS)
# Out:
# 84.28397257011645
